# %% [markdown]
# <a href="https://colab.research.google.com/github/viett887g/hoiquy/blob/main/hoiquytuyentinh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statistics as std
import numpy as np
import os

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
  x=np.array([1,2,3,4,5])
  y=np.array([2,9,1,7,6])
  stdx=std.stdev(x)
  stdy=std.stdev(y)
  r = np.corrcoef(x, y)
  r=r[1,0]
  B1 = r * (stdy / stdx)
  
  B0 =std.mean(y)-B1*std.mean(x)
  a1=B0+B1
  a2=B0+B1*2
  a3=B0+B1*3
  a4=B0+B1*4
  a5=B0+B1*5
  h0=np.array([a1,a2,a3,a4,a5])
  m=x.shape[0]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cost=(1/(2*m))*np.sum((h0 - y)**2)
print(cost)
# Out:
# 4.243144437846028

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=a1-1.2*(1/m)*np.dot(np.sum(h0-y),x)
print(a)
# Out:
# [3.68784943 3.68784943 3.68784943 3.68784943 3.68784943]
